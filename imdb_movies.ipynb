# %% [markdown]
# <a href="https://colab.research.google.com/github/anoop23822/anoop23822/blob/main/imdb_movies.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv("/content/movies_metadata - movies_metadata.csv")
df.head(2)
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
#
#                                homepage    id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story   862  tt0114709                en
# 1                                   NaN  8844  tt0113497                en
#
#   original_title                                           overview  ...  \
# 0      Toy Story  Led by Woody, Andy's toys live happily in his ...  ...
# 1        Jumanji  When siblings Judy and Peter discover an encha...  ...
#
#      revenue runtime                                   spoken_languages  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 25 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   adult                  50 non-null     bool
#  1   belongs_to_collection  10 non-null     object
#  2   budget                 50 non-null     int64
#  3   genres                 50 non-null     object
#  4   homepage               5 non-null      object
#  5   id                     50 non-null     int64
#  6   imdb_id                50 non-null     object
#  7   original_language      50 non-null     object
#  8   original_title         50 non-null     object
#  9   overview               49 non-null     object
#  10  popularity             50 non-null     object
#  11  poster_path            50 non-null     object
#  12  production_companies   50 non-null     object
#  13  production_countries   50 non-null     object
# ...

# %%
third = df.iloc[2]['original_title']
print(third)
# Out:
# Grumpier Old Men

# %%
df.shape
# Out:
# (50, 25)

# %%
df[['title','genres']]
# Out:
#                                                 title  \
# 0                                           Toy Story
# 1                                             Jumanji
# 2                                    Grumpier Old Men
# 3                                   Waiting to Exhale
# 4                         Father of the Bride Part II
# 5                                                Heat
# 6                                             Sabrina
# 7                                        Tom and Huck
# 8                                        Sudden Death
# 9                                           GoldenEye
# 10                             The American President
# 11                        Dracula: Dead and Loving It
# 12                                              Balto
# 13                                              Nixon
# 14                                   Cutthroat Island
# 15                                             Casino
# ...

# %%
df[df['original_title']== 'Grumpier Old Men']
# Out:
#    adult                              belongs_to_collection  budget  \
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...       0
#
#                                               genres homepage     id  \
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...      NaN  15602
#
#      imdb_id original_language    original_title  \
# 2  tt0113228                en  Grumpier Old Men
#
#                                             overview  ... revenue runtime  \
# 2  A family wedding reignites the ancient feud be...  ...       0     101
#
#                            spoken_languages    status  \
# 2  [{'iso_639_1': 'en', 'name': 'English'}]  Released
#
#                                              tagline             title  video  \
# 2  Still Yelling. Still Fighting. Still Ready for...  Grumpier Old Men  FALSE
#
#   vote_average vote_count Unnamed: 24
# 2          6.5       92.0         NaN
#
# [1 rows x 25 columns]

# %%
df = df.set_index('original_title')
result = df.loc['Grumpier Old Men']
print(result)
# Out:
# adult                                                                False
# belongs_to_collection    {'id': 119050, 'name': 'Grumpy Old Men Collect...
# budget                                                                   0
# genres                   [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# homepage                                                               NaN
# id                                                                   15602
# imdb_id                                                          tt0113228
# original_language                                                       en
# overview                 A family wedding reignites the ancient feud be...
# popularity                                                         11.7129
# poster_path                               /6ksm1sjKMFLbO7UY2i6G1ju9SML.jpg
# production_companies     [{'name': 'Warner Bros.', 'id': 6194}, {'name'...
# ...

# %%
df2 = df.sort_values('release_date', ascending=True)

# %%
df2
# Out:
#                                   adult  \
# original_title
# Father of the Bride Part II       False
# When Night Is Falling             False
# La Cité des Enfants Perdus        False
# To Die For                        False
# Pocahontas                        False
# Babe                              False
# The Usual Suspects                False
# Clueless                          False
# Dangerous Minds                   False
# Mortal Kombat                     False
# Se7en                             False
# Persuasion                        False
# How To Make An American Quilt     False
# Dead Presidents                   False
# Assassins                         False
# Across the Sea of Time            False
# Now and Then                      False
# Get Shorty                        False
# Powder                            False
# Copycat                           False
# Leaving Las Vegas                 False
# Toy Story                         False
# ...
